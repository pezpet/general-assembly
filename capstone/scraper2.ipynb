# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from requests import get
import json
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## World Surf League Scores
#
# I'm going to focus on the Pipeline Masters first. It is the marquee event of the Championship Tour and is run every year (**verify**).

# %% [markdown]
# ### Get HTML soup and review
#
# Use Beautiful Soup to get html from World Surf League event pages. Each page has the final result and a 'carousel' that links to previous rounds.

# %%
# Starting URLs
pipe_2008_url = "https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters"
res = get(pipe_2008_url)
soup = BeautifulSoup(res.content)

# %% [markdown]
# From inspecting page source I have found an unordered list with useful urls to get all scores from each event

# %%
# Find all list items within the event rounds div
carousel = soup.find('div', id='event-rounds').find_all('li')

# %%
# Visual check of event round urls and round names/numbers
for horse in carousel:
    link_elements = horse.find_all('a')
    print(link_elements)
# Out:
# [<a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=4">Round 2</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=3">Round 1</a>, <a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=5">Round 3</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=4">Round 2</a>, <a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=6">Round 4</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=5">Round 3</a>, <a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=7">Quarterfinal</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=6">Round 4</a>, <a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=52">Semifinal</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=7">Quarterfinal</a>, <a class="next" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=77">Final</a>]
# [<a class="previous" data-no-scroll="true" data-request-name="eventRound" href="/events/2008/mct/75/billabong-pipeline-masters?roundId=52">Semifinal</a>]

# %%
# Build a dict of urls and round names
round_urls = []
for horse in carousel:
    link_elements = horse.find_all('a')
    for link in link_elements:
        url_dict = {}
        url_dict['round'] = link.text
        # Add endpoint for ease of use later
        url_dict['url'] = "https://www.worldsurfleague.com" + link['href']
        print(link['href'], link.text)
        round_urls.append(url_dict)
# Out:
# /events/2008/mct/75/billabong-pipeline-masters?roundId=4 Round 2
# /events/2008/mct/75/billabong-pipeline-masters?roundId=3 Round 1
# /events/2008/mct/75/billabong-pipeline-masters?roundId=5 Round 3
# /events/2008/mct/75/billabong-pipeline-masters?roundId=4 Round 2
# /events/2008/mct/75/billabong-pipeline-masters?roundId=6 Round 4
# /events/2008/mct/75/billabong-pipeline-masters?roundId=5 Round 3
# /events/2008/mct/75/billabong-pipeline-masters?roundId=7 Quarterfinal
# /events/2008/mct/75/billabong-pipeline-masters?roundId=6 Round 4
# /events/2008/mct/75/billabong-pipeline-masters?roundId=52 Semifinal
# /events/2008/mct/75/billabong-pipeline-masters?roundId=7 Quarterfinal
# /events/2008/mct/75/billabong-pipeline-masters?roundId=77 Final
# /events/2008/mct/75/billabong-pipeline-masters?roundId=52 Semifinal

# %%
# With help from https://stackoverflow.com/questions/11092511/list-of-unique-dictionaries
# Keep only unique values
round_urls_unique = list({unique['url']:unique for unique in round_urls}.values())
round_urls_unique
# Out:
# [{'round': 'Round 2',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=4'},
#  {'round': 'Round 1',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=3'},
#  {'round': 'Round 3',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=5'},
#  {'round': 'Round 4',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=6'},
#  {'round': 'Quarterfinal',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=7'},
#  {'round': 'Semifinal',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=52'},
#  {'round': 'Final',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters?roundId=77'}]

# %% [markdown]
# ### Get scores for every round in an event

# %%
# Get scores function takes the url dict and gets scores for each round of the event
def get_scores(url_list_of_dicts, event_name):
    data = []
    # Iterate through event rounds
    for round in url_list_of_dicts:
        # Get html soup
        res = get(round['url'])
        round_soup = BeautifulSoup(res.content)
        # Get list of athlete names
        athletes = round_soup.find_all("span", class_="athlete-name")

        # Get list of scores lists
        scores = round_soup.find_all("div", class_="all-waves all-waves-grid")

        # Go through athletes
        for i in range(len(athletes)):

            # Create dict to save scores
            athlete_scores = {}

            # Save event name
            athlete_scores["event"] = event_name

            # Save round name
            athlete_scores["round"] = round['round']

            # Save heat number
            athlete_scores["heat"] = (
                athletes[i]
                .find_parent("div", class_="bd new-heat-bd")
                .find_previous_sibling()
                .find("span", class_="new-heat-hd-name")
                .text
            )

            # Athlete name
            athlete_scores["name"] = athletes[i].text

            # Empty list for athletes scores in that heat
            athlete_scores["scores"] = []

            # Scores list
            per_wave_scores = scores[i].find_all("span", class_="score")

            # Append scores
            for b in range(len(per_wave_scores)):
                try:
                    athlete_scores["scores"].append(float(per_wave_scores[b].text))
                except:
                    continue

            # Add to data list
            data.append(athlete_scores)

        # Sleep
        time.sleep(1)

    return data

# %%
pipe_2008_scores = get_scores(round_urls_unique, 'Pipe 2008')

# %%
pd.DataFrame(pipe_2008_scores)
# Out:
#          event      round     heat               name  \
# 0    Pipe 2008    Round 2  Heat 1   Kamalei Alexander
# 1    Pipe 2008    Round 2  Heat 1        Mikael Picon
# 2    Pipe 2008    Round 2  Heat 2        Evan Valiere
# 3    Pipe 2008    Round 2  Heat 2       Mick Campbell
# 4    Pipe 2008    Round 2  Heat 3       Jamie O'Brien
# ..         ...        ...      ...                ...
# 122  Pipe 2008  Semifinal  Heat 1           Tim Reyes
# 123  Pipe 2008  Semifinal  Heat 2          Chris Ward
# 124  Pipe 2008  Semifinal  Heat 2       Adrian Buchan
# 125  Pipe 2008      Final  Heat 1        Kelly Slater
# 126  Pipe 2008      Final  Heat 1          Chris Ward
#
#                                             scores
# 0                    [6.33, 3.0, 5.57, 5.07, 0.67]
# 1               [2.67, 1.0, 5.17, 5.77, 5.9, 4.43]
# 2        [2.67, 0.57, 1.57, 5.5, 1.67, 1.37, 9.07]
# 3                     [1.5, 3.17, 5.67, 1.0, 8.67]
# 4    [5.0, 6.0, 1.33, 3.83, 1.73, 2.23, 5.73, 9.0]
# ..                                             ...
# 122                   [2.07, 2.57, 6.5, 9.1, 5.67]
# 123             [6.83, 1.13, 1.23, 9.63, 4.5, 1.5]
# 124   [4.33, 1.0, 1.43, 1.4, 3.5, 5.83, 2.67, 0.2]
# 125         [1.4, 2.0, 7.17, 0.73, 1.1, 1.0, 6.83]
# 126                  [0.87, 2.33, 3.5, 3.73, 0.67]
#
# [127 rows x 5 columns]

# %% [markdown]
# ### Get all scores for all events in all years

# %%
yearly_urls = []
for year in range(2008, 2020):
    yearly_urls.append(f'https://www.worldsurfleague.com/events/{year}/mct?all=1')

# %%
event_urls = []
for year in yearly_urls:
    res = get(year)
    soup = BeautifulSoup(res.content)
    for each in soup.find_all("a", class_="event-schedule-details__event-name"):
        event = {}
        event['name'] = each.text
        event['url'] = each['href']
        event_urls.append(event)
    time.sleep(1)

event_urls
# Out:
# [{'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/4/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/8/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/20/billabong-pro-teahupoo'},
#  {'name': 'Globe Pro Fiji',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/24/globe-pro-fiji'},
#  {'name': 'Billabong Pro J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/31/billabong-pro-j-bay'},
#  {'name': 'Rip Curl Pro Search Bali',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/37/rip-curl-pro-search-bali'},
#  {'name': 'Boost Mobile Pro',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/48/boost-mobile-pro'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/54/quiksilver-pro-france'},
#  {'name': 'Billabong Pro Mundaka',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/55/billabong-pro-mundaka'},
#  {'name': 'Hang Loose Santa Catarina Pro',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/66/hang-loose-santa-catarina-pro'},
#  {'name': 'Billabong Pipeline Masters',
#   'url': 'https://www.worldsurfleague.com/events/2008/mct/75/billabong-pipeline-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/83/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/91/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/95/billabong-pro-teahupoo'},
#  {'name': 'Hang Loose Santa Catarina Pro',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/99/hang-loose-santa-catarina-pro'},
#  {'name': 'Billabong Pro J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/104/billabong-pro-j-bay'},
#  {'name': 'Hurley Pro Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/116/hurley-pro-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/117/quiksilver-pro-france'},
#  {'name': 'Billabong Pro Mundaka',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/121/billabong-pro-mundaka'},
#  {'name': 'Rip Curl Search',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/126/rip-curl-search'},
#  {'name': 'Billabong Pipeline Masters',
#   'url': 'https://www.worldsurfleague.com/events/2009/mct/138/billabong-pipeline-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/148/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/156/rip-curl-pro-bells-beach'},
#  {'name': 'Santa Catarina Pro',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/162/santa-catarina-pro'},
#  {'name': 'Billabong Pro J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/177/billabong-pro-j-bay'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/187/billabong-pro-teahupoo'},
#  {'name': 'Hurley Pro Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/191/hurley-pro-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/196/quiksilver-pro-france'},
#  {'name': 'Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/202/rip-curl-pro-portugal'},
#  {'name': 'Rip Curl Search',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/210/rip-curl-search'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2010/mct/220/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/235/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/259/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/275/billabong-rio-pro'},
#  {'name': 'Billabong Pro J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/294/billabong-pro-j-bay'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/324/billabong-pro-teahupoo'},
#  {'name': 'Quiksilver Pro New York',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/336/quiksilver-pro-new-york'},
#  {'name': 'Hurley Pro Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/340/hurley-pro-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/347/quiksilver-pro-france'},
#  {'name': 'Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/352/rip-curl-pro-portugal'},
#  {'name': 'Rip Curl Search',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/361/rip-curl-search'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2011/mct/368/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/388/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/406/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/415/billabong-rio-pro'},
#  {'name': 'Volcom Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/420/volcom-fiji-pro'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/458/billabong-pro-teahupoo'},
#  {'name': 'Hurley Pro Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/484/hurley-pro-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/487/quiksilver-pro-france'},
#  {'name': 'Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/493/rip-curl-pro-portugal'},
#  {'name': "O'Neill Coldwater Classic Santa Cruz",
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/497/oneill-coldwater-classic-santa-cruz'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2012/mct/504/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/519/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/529/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/535/billabong-rio-pro'},
#  {'name': 'Volcom Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/540/volcom-fiji-pro'},
#  {'name': 'Oakley Pro Bali',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/547/oakley-pro-bali'},
#  {'name': 'Billabong Pro Teahupoo',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/573/billabong-pro-teahupoo'},
#  {'name': 'Hurley Pro Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/589/hurley-pro-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/594/quiksilver-pro-france'},
#  {'name': 'Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/596/rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2013/mct/615/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/639/quiksilver-pro-gold-coast'},
#  {'name': 'Drug Aware Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/649/drug-aware-margaret-river-pro'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/655/rip-curl-pro-bells-beach'},
#  {'name': 'Billabong Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/664/billabong-rio-pro'},
#  {'name': 'Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/668/fiji-pro'},
#  {'name': 'J-Bay Open',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/674/j-bay-open'},
#  {'name': 'Billabong Pro Tahiti',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/698/billabong-pro-tahiti'},
#  {'name': 'Hurley Pro at Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/708/hurley-pro-at-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/713/quiksilver-pro-france'},
#  {'name': 'Moche Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/719/moche-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2014/mct/730/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1207/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1222/rip-curl-pro-bells-beach'},
#  {'name': 'Drug Aware Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1226/drug-aware-margaret-river-pro'},
#  {'name': 'Oi Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1234/oi-rio-pro'},
#  {'name': 'Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1236/fiji-pro'},
#  {'name': 'J-Bay Open',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1244/j-bay-open'},
#  {'name': 'Billabong Pro Tahiti',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1267/billabong-pro-tahiti'},
#  {'name': 'Hurley Pro at Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1281/hurley-pro-at-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1302/quiksilver-pro-france'},
#  {'name': 'Moche Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1307/moche-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2015/mct/1317/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1399/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1413/rip-curl-pro-bells-beach'},
#  {'name': 'Drug Aware Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1418/drug-aware-margaret-river-pro'},
#  {'name': 'Oi Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1434/oi-rio-pro'},
#  {'name': 'Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1443/fiji-pro'},
#  {'name': 'J-Bay Open',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1457/j-bay-open'},
#  {'name': 'Billabong Pro Tahiti',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1484/billabong-pro-tahiti'},
#  {'name': 'Hurley Pro at Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1495/hurley-pro-at-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1513/quiksilver-pro-france'},
#  {'name': 'MEO Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1522/meo-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2016/mct/1540/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1800/quiksilver-pro-gold-coast'},
#  {'name': 'Drug Aware Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1809/drug-aware-margaret-river-pro'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1822/rip-curl-pro-bells-beach'},
#  {'name': 'Oi Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1854/oi-rio-pro'},
#  {'name': 'Outerknown Fiji Pro',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1867/outerknown-fiji-pro'},
#  {'name': 'Corona Open J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1900/corona-open-j-bay'},
#  {'name': 'Billabong Pro Tahiti',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1920/billabong-pro-tahiti'},
#  {'name': 'Hurley Pro at Trestles',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1935/hurley-pro-at-trestles'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1950/quiksilver-pro-france'},
#  {'name': 'MEO Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1961/meo-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2017/mct/1979/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2647/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2671/rip-curl-pro-bells-beach'},
#  {'name': 'Oi Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2705/oi-rio-pro'},
#  {'name': 'Corona Bali Protected',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2714/corona-bali-protected'},
#  {'name': 'Uluwatu CT/ Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2686/uluwatu-ct-margaret-river-pro'},
#  {'name': 'Corona Open J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2747/corona-open-j-bay'},
#  {'name': "Tahiti Pro Teahupo'o",
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2774/tahiti-pro-teahupoo'},
#  {'name': 'Surf Ranch Pro',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2791/surf-ranch-pro'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2803/quiksilver-pro-france'},
#  {'name': 'MEO Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2825/meo-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2018/mct/2856/billabong-pipe-masters'},
#  {'name': 'Quiksilver Pro Gold Coast',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2908/quiksilver-pro-gold-coast'},
#  {'name': 'Rip Curl Pro Bells Beach',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2909/rip-curl-pro-bells-beach'},
#  {'name': 'Corona Bali Protected',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2912/corona-bali-protected'},
#  {'name': 'Margaret River Pro',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2913/margaret-river-pro'},
#  {'name': 'Oi Rio Pro',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2916/oi-rio-pro'},
#  {'name': 'Corona Open J-Bay',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2917/corona-open-j-bay'},
#  {'name': "Tahiti Pro Teahupo'o",
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2919/tahiti-pro-teahupoo'},
#  {'name': 'Freshwater Pro',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2920/freshwater-pro'},
#  {'name': 'Quiksilver Pro France',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2923/quiksilver-pro-france'},
#  {'name': 'MEO Rip Curl Pro Portugal',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2924/meo-rip-curl-pro-portugal'},
#  {'name': 'Billabong Pipe Masters',
#   'url': 'https://www.worldsurfleague.com/events/2019/mct/2927/billabong-pipe-masters'}]
